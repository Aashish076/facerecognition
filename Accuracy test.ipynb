# %%
import face_recognition
import cv2
import numpy as np
import os
#import pandas as pd

# Load an image file and create a face encoding
aashish_image = face_recognition.load_image_file(r"C:\Users\aashi\OneDrive\Desktop\JUPTER PHOTO\AAshish\aashish (1).jpg")
aashish_face_encoding = face_recognition.face_encodings(aashish_image)[0]
print("aashish")

# Create arrays of known face encodings and their names
known_face_encodings = [
    aashish_face_encoding,
]
known_face_names = [
    "aashish",
]
# Dictionary to map unknown image filenames to their actual names (ground truth)
ground_truth = {
   "aashish": "aashish.jpg" ,
}
# Out:
# aashish

# %%
#import os
# Initialize some variables

face_locations = []
face_encodings = []
face_names = []

# Process unknown images
path = r"C:\Users\aashi\OneDrive\Desktop\unkown_Aashish"
correct_predictions = 0
total_predictions = 0


for (root, dirs, files) in os.walk(path, topdown=True):
    for file in files:
        unknown_image_path = os.path.join(root, file)  # Use os.path.join here
        if not os.path.exists(unknown_image_path):
            print(f"File not found: {unknown_image_path}")
            continue



# for (root, dirs, files) in os.walk(path, topdown=True):
#     for file in files:
        unknown_image = face_recognition.load_image_file(unknown_image_path)  # Correct path usage
        face_locations = face_recognition.face_locations(unknown_image)
        face_encodings = face_recognition.face_encodings(unknown_image, face_locations)
        face_names = []
        for face_encoding in face_encodings:
            matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
            name = "Unknown"
            face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
            best_match_index = np.argmin(face_distances)
            if matches[best_match_index]:
                name = known_face_names[best_match_index]
                
            face_names.append(name)
            print(f"File: {file}, Predicted Name: {name}")
            file_key = file.split(' ')[0] 
            db_filename=ground_truth[file_key]
            name_db_filename=db_filename.split(".")[0]
            
            
            
            if True:
                print(name)
                print( name_db_filename)
                if name == name_db_filename :
                    correct_predictions += 1

                    
                    #print(correct_predictions)
                    total_predictions += 1
                else:
                    total_predictions+=1
            print("running percentage=",(correct_predictions/total_predictions)*100)
            

# Calculate and print the accuracy
if total_predictions > 0:
    accuracy = (correct_predictions / total_predictions) * 100
    print(f"Accuracy: {accuracy:.2f}%")
else:
    print("No predictions were made.")
# Out:
# File: aashish (1).jpg, Predicted Name: aashish
# aashish
# aashish
# running percentage= 100.0
# File: aashish (1).png, Predicted Name: aashish
# aashish
# aashish
# running percentage= 100.0
# File: aashish (10).jpg, Predicted Name: aashish
# aashish
# aashish
# running percentage= 100.0
# File: aashish (11).JPG, Predicted Name: aashish
# aashish
# aashish
# running percentage= 100.0
# File: aashish (12).jpg, Predicted Name: aashish
# aashish
# aashish
# running percentage= 100.0
# File: aashish (13).jpg, Predicted Name: aashish
# aashish
# aashish
# running percentage= 100.0
# File: aashish (16).jpg, Predicted Name: aashish
# aashish
# aashish
# running percentage= 100.0
# File: aashish (17).JPG, Predicted Name: aashish
# aashish
# aashish
# running percentage= 100.0
# File: aashish (18).JPG, Predicted Name: aashish
# aashish
# aashish
# running percentage= 100.0
# File: aashish (19).jpg, Predicted Name: aashish
# aashish
# aashish
# running percentage= 100.0
# ...
